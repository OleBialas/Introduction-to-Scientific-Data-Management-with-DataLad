# %% [markdown]
# ## Creating Local Backups
# - Create a local sibling from a bare git repository
# - use `datalad push` and `datalad update`

# %% [markdown]
# ## Using Open Science Repositories
# - create a sibling on either GIN or OSF

# %% [markdown]
# ## Using GitHub for Visibility
# - create and additional sibling on GitHub
